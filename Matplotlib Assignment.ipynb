# %% [markdown]
# # Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %%
Matplotlib is a comprehensive library for creating static, animated,
and interactive visualizations in Python. Matplotlib makes easy things easy 
and hard things possible. Create publication quality plots. Make interactive figures that can zoom, pan, update.

Five Plots:
    *Line Plot
    *Scatter Plot
    *Bar Plot
    *Histogram Plot
    *Pie Plot

# %% [markdown]
# # Line Plot

# %%
import numpy as np
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Plot')
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.scatter(x, y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot')
plt.show()

# %% [markdown]
# # Bar Plot

# %%
data = [1, 2, 3, 4]
values = [30, 50, 20, 40]

plt.bar(data, values)
plt.xlabel('data')
plt.ylabel('Values')
plt.title('Bar Chart')
plt.show()

# %% [markdown]
# # Histogram Plot

# %%
import numpy as np
data = np.random.randn(1000)
plt.hist(data, bins=10)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %% [markdown]
# # Pie Plot

# %%
names = ['Aruvi', 'Institute', 'Students', 'Ratchagan']
sizes = [25, 30, 20, 25]

plt.pie(sizes, labels=names)
plt.title('Pie Chart')
plt.show()

# %% [markdown]
# # Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot.

# %%
Scatter Plot:
   * A scatter plot is a data visualization that displays the values of two different variables as points.
   * Additional variables can be encoded by labels, markers, color, 
    transparency, size (bubbles), and creating 'small multiples' of scatter plots.

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(42)
num_points = 100
x = np.random.rand(num_points)
y = 2 * x + 1 + 0.1 * np.random.randn(num_points)

# Create a scatter plot
plt.scatter(x, y, color='blue', marker='o', label='Data Points')
plt.title('Scatter Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Q3.Why is the subplot() function used? Draw four line plots using the subplot() function.

# %%
Subplot:
    The subplots() function in the Pyplot module of the Matplotlib library is used to create a 
    figure and a set of subplots. Parameters: This method accept the following parameters that are 
        described below: nrows, ncols : These parameter are the number of rows/columns of the subplot grid.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
x=np.linspace(0,5,21)
x
y1=2**x
print(y1)
y2=5**x
print(y2)
y3=8**x
print(y3)
y4=11**x
print(y4)
plt.subplot(2,2,1)  
plt.plot(x,y1,'hotpink')
plt.subplot(2,2,2) 
plt.plot(x,y2,'yellow')
plt.subplot(2,2,3) 
plt.plot(x,y3,'hotpink')
plt.subplot(2,2,4)   
plt.plot(x,y4,'yellow')
# Out:
# [ 1.          1.18920712  1.41421356  1.68179283  2.          2.37841423
#   2.82842712  3.36358566  4.          4.75682846  5.65685425  6.72717132
#   8.          9.51365692 11.3137085  13.45434264 16.         19.02731384
#  22.627417   26.90868529 32.        ]
# [1.00000000e+00 1.49534878e+00 2.23606798e+00 3.34370152e+00
#  5.00000000e+00 7.47674391e+00 1.11803399e+01 1.67185076e+01
#  2.50000000e+01 3.73837195e+01 5.59016994e+01 8.35925381e+01
#  1.25000000e+02 1.86918598e+02 2.79508497e+02 4.17962691e+02
#  6.25000000e+02 9.34592988e+02 1.39754249e+03 2.08981345e+03
#  3.12500000e+03]
# [1.00000000e+00 1.68179283e+00 2.82842712e+00 4.75682846e+00
#  8.00000000e+00 1.34543426e+01 2.26274170e+01 3.80546277e+01
#  6.40000000e+01 1.07634741e+02 1.81019336e+02 3.04437021e+02
#  5.12000000e+02 8.61077929e+02 1.44815469e+03 2.43549617e+03
#  4.09600000e+03 6.88862343e+03 1.15852375e+04 1.94839694e+04
#  3.27680000e+04]
# [1.00000000e+00 1.82116029e+00 3.31662479e+00 6.04010535e+00
# ...

# %% [markdown]
# # Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %%
Barplot:
    * A barplot (or barchart) is one of the most common types of graphic.
    * It shows the relationship between a numeric and a categoric variable

# %%
x=np.array(['A','B','C','D'])
y=np.array([3,8,1,10])
plt.barh(x,y,color='y',height=2)
plt.xlabel('y Values')
plt.ylabel('x alues')
plt.title('Bar Plot')
# Out:
# Text(0.5, 1.0, 'Bar Plot')

# %% [markdown]
# # Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

# %%
Boxplot:
    * Box plots provide a quick visual summary of the variability of values in a dataset. 
    * They show the median, upper and lower quartiles, minimum and maximum values, and any outliers in the dataset. 
    * Outliers can reveal mistakes or unusual occurrences in data.

# %%
import matplotlib.pyplot as plt
import numpy as np
data = [5,10, 17, 20, 25, 32, 35, 40, 48, 55]
plt.boxplot(data)
plt.xlabel('Data')
plt.ylabel('Values')
plt.title('Box Plot')
# Out:
# Text(0.5, 1.0, 'Box Plot')
